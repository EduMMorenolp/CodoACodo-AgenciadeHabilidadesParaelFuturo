# %% [markdown]
# # Excepciones en Python
# ## Manejo de errores

# %%
numerador = int(input('Ingrese el numerador: '))
denominador = int(input('Ingrese el denominador (distinto de CERO): '))

try :
  cociente = numerador / denominador
  print(nombre)

except NameError:
  print('Tenemos problemas con algun nombre')

except ZeroDivisionError:
  print('Tenemos problemas con algun denominador en CERO')

else:
  print('El cociente es igual a', cociente)

finally:
  print('Ya tengo las excepciones bajo control')
