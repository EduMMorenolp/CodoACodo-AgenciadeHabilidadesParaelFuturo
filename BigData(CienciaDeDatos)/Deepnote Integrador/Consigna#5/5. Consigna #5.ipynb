# %% [markdown]
# # Consignas #5:
# ---
#
# ### CONSIGNA #5
# **A.** Usaremos la BBDD **<font color='red'>netflix_oscar.db</font>** que contiene la información de las tres tablas manteniendo el contexto deepnote. !Esta BBDD ha sido modificada de tal forma que los todos títulos de la netflix.content sean únicos¡
#
# **C. Contexto**
# 1. Te entregamos una BBDD relacional y en SQLite para practicar. Esta BBDD no está completa ni tiene todas las variables. Puede tener un comportamiento validable. Contiene errores que iremos trabajando durante el desarrollo del curso. No es el objetivo detectar todos los errores, pero sí aprender a reconocerlos y tratarlos adecuadamente.
# 1. La tabla **'content'** tiene información de los contenidos de netflix en general.
# 1. La tabla **'production'** tiene información de los contenidos originales de netflix.
# 1. La tabla **'oscar'** que esta relacionada con los premios a la industria del entretenimiento, especificamente el cine.
# 1. Para referirnos a las hojas de calculo las usaremos la sigla HHCC
#
# **D. Recuerda que:**
# 1. Los ejercicios marcados como **"Desafíos"** son optativos, <u>de entrega no obligatoria</u> pero contribuyen a tu ejercitación como profesional.
# 1. Los enunciados contienen indicaciones mínimas que puedes mejorar. Sé creativo y piensa como si ya fueses un profesional de los datos.
# 1. El material final es un TU PORTAFOLIO piensa en ello para que puedas hacer tu proyecto como te lo pedimos, pero no estaría mal hacer uno paralelo donde puedas hacer más aportes de tu parte.
#
# Recuerda mantener actualizado tu Deepnote.
#
# ### ¡Éxito y vamos... sigamos que pronto concluye y tu portafolio va creciendo!

# %% [markdown]
# ## 1.- Conectar tu BBDD desde Colab o desde Deepnote y realizar las funciones principales del CRUD a la BBDD netflix
# Durante la desde el **05/11/2023** hasta el **27/11/2023**, se deben cubrir los siguientes objetivos:
#
# 1. **Conectar la BBDD**:
#     * Puedes seguir el [VIDEO](https://youtu.be/wIQRoFYXK6E)
#     * Descarga la BBDD **<font color='red'>netflix_oscar.db</font>** que tienes ubicada en data/SQLite que te hemos compartido. Si bien esta BBDD se parece a la que has trabajado es distinta así que debes trabajar con ella.
#     * Con el código python colocado abajo de este texto vas a realizar la conexión y una prueba básica. Para ello **solo** debes cambiar la palabra reservada **<font color='#2762b1'>`pass`</font>** por el código que consideres necesario para cada una de las funciones: `# CONEXION get_connetion()` y para `# DESCONEXION close_connetion()`.

# %%
import sqlite3 as sq3

# CONEXION
def get_connetion():
    global database
    database = 'netflix_oscar.db'
    pass
    return conn

# DESCONEXION
def close_connetion():
    pass
      
# CONSULTA
def read_database():
    is_conn = False
    try:
        global conn
        global cursor
        conn = get_connetion()
        cursor = conn.cursor()
        cursor.execute('SELECT sqlite_version()') # para la versión de SQL es @@version
        db_version = cursor.fetchone()
    except (Exception, sq3.Error) as error:
        print(f'Houston tenemos problemas: {error}')
    else:
        print(f'Estamos conectados en la BBDD {database}... ')
        print(f'Con la versión de SQLite: {db_version}')
        is_conn = True
    finally:
        if is_conn:
            close_connetion()
            print('Se ha cerrado la conexión')

read_database()
# Out:
# Houston tenemos problemas: name 'conn' is not defined
# Se ha cerrado la conexión

# %% [markdown]
# **1.1. Desde deepnote**:
# >    A. Crea una carpeta dentro de **Mi_proyecto** llamala **crud** .
# >    B. Coloca la BBDD **<font color='red'>netflix_oscar.db</font>** en la carpeta crud.
# >    C. En una celda de cógido de una notebook donde entregues las consigna #5 copia y pega el código que está arriba, modificado adecuadamente para que pueda realizar la conexión y la desconexión.

# %% [markdown]
# **1.2. Desde colab**:
# >    A. En tu Drive en la carpeta **Colab Notebooks** coloca la BBDD **<font color='red'>netflix_oscar.db</font>**.
# >    B. Crea un archivo en la misma carpeta, llamalo **conexion_colab**, recuerda que debes compartirlo con capacidad de edición.
# >    C. Copia y pega el código que está arriba, modificado adecuadamente para que pueda realizar la conexión y la desconexión.
# >    **Nota** una primera modificacion importante es añadir la importación de libreria a drive y luego iniciar la conexión a drive como se muestra a continuación:
# ```python
# from google.colab import drive
# from google.colab import auth
#
# drive.mount('/content/drive')
#
# ```

# %% [markdown]
# 2. **Funciones basicas en bases de datos (CRUD)**:
# Puedes seguir el [VIDEO](https://youtu.be/5xn3qP2qHmo) para una explicación general del crud.
#   **A. Preparatorio para realizarlo**:
#   + Descarga el archivo **<font color='red'>crud_netflix.py</font>** y colocalo en una carpeta **crud**.
#   + Guarda el archivo como **<font color='red'>crud_netflix_mod.py</font>**
#   + Instala/importa las librerias virtualenv.
#   + Crea un entorno virtual para la carpeta **crud**. Puedes seguir el [VIDEO](https://youtu.be/wIQRoFYXK6E).
#   + La tabla de la BBDD que se va a trabajar es `content`.
#   Puedes ver el [VIDEO](https://youtu.be/ntejyxGteWY) para entender la interfaz gráfica de manera genérica.

# %% [markdown]
#   **B. Leer el código**:
#   + Revisar y entender las funciones:
#   `limpiar()`, `listar_asc()`,`mensaje_noconectado()`,`mensaje_campo_obligatorio()`, `mensaje_registro()`, `chequear_campo()`, `leer_campo()` y `rellenar_campos()`
#
# Puedes ver el [VIDEO](https://youtu.be/mJOosrpnWz4) para entender un poco estas funciones de la interfaz gráfica de manera genérica.
#   **C. Contexto que debe considerarse para el CRUD**
#   + La operación en tkinter **Actualizar/Update** debe ejecutarse siempre después de la operación en tkinter  **Leer/Read/Buscar**.
#   + Los campos que se van a consultar/impactar son los siguientes, con las condiciones que se deben tomar en cuenta para cada caso:

# %% [markdown]
# <table>
#     <tr>
#         <th colspan="2"> </th>
#         <th colspan="4", style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>Operación en la BBDD</font></th>
#     </tr>
#     <tr>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>Campos de la BBDD</th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>Tipo de campo en tkinter</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>Crear/Create</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>Leer/Read</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>Actualizar/Update</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center"><font color='blue'>Borrar/Delete</font></th>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><b>title_content</b></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Input</td>
#         <td rowspan="8"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Obligatorio</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Obligatorio</td>
#         <td rowspan="8"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Posible</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Obligatorio</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><b>type</b></td>
#         <td rowspan="6"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Lista desplegable</td>
#         <td rowspan="7"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">-</td>
#         <td rowspan="7"; style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">-</td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><b>rating</b></td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><b>listed_in</b></td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><b>director</b></td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><b>country</b></td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><b>duration</b></td>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><b>release_year</b></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px; text-align: center">Slider</td>
#     </tr>
# </table>
#
# En el código que descargaste, completa las funciones siguientes:

# %% [markdown]
# ##### D. Conexión
# + `def conectar` para conectarte de la BBDD está ubicado debajo del comentario **<font color='#406040'># Conexión</font>**.
# Que debe hacer la función:
# >   1. Conectarse a la BBDD, creando los objetos **conn** para la conexión y **cur** para el cursor
# >   2. Cambiar apropiadamente la variable is_check_conn
# >   3. Enviar través del objeto messagebox y el método showinfo con el título para la ventana `STATUS` y el mensaje `¡Conectado a la BBDD!`. (Observa la función `mostrar_acercade()` te puede ayudar para realizar este punto)

# %% [markdown]
# ##### E. Desconexión
# + `def desconectar` para desconectarte de la BBDD está ubicado debajo del comentario **<font color='#406040'># Desconexión</font>**.
# ¿Qué debe hacer la función?:
# >   1. Desconectarse a la BBDD, cerrando los objetos conn y cur
# >   2. Cambiar apropiadamente la variable is_check_conn
# >   3. Enviar, a través del objeto messagebox y su método showinfo con el título para la ventana `STATUS`, el mensaje `¡Desconectado de la BBDD!`. (Observa la función `mostrar_acercade()` te puede ayudar para realizar este punto)

# %% [markdown]
# ##### F. Crear
# + `def crear` para insertar registros a la BBDD está ubicado debajo del comentario **<font color='#406040'>#  CREATE</font>**.
# ¿Qué debe hacer la función?:
# >   1. Verificar que los campos obligatorios no esten en sus condiciones iniciales menos release_year.
# >   2. Si cualquiera está en sus condiciones iniciales  debe enviar, a través del objeto messagebox y el método showinfo con el título para la ventana `IMPORTANTE`, el mensaje `¡Es obligatorio informar cada uno de los campos!`.
# >   3. Si todos no tienen sus condiciones iniciales (se supone que estan listos para crear un registro), llamar a la función `leer_campo()` usando entre los  argumentos el título y almacenar el resultado de la query. **<font color='blue'>Tips</font>** la función requiere 3 argumentos la variable que lee desde la interfaz, el nombre del campo (un string) y el nombre de la columna de la BBDD.
# >   4. Si ya existe ese título, usando la función `mensaje_campo_existe_o_no(title_content.get(), 'título', 'ya')` con esos argumentos, debe mostrar un mensaje avisando que ese campo ya existe. **<font color='blue'>Tips</font>** no debería traer ningun resultado.
# >   5. Si no existe debe:
# >   >   5.1. Con la siguiente tupla `datos = type.get(), title_content.get(), director.get(), country.get(), release_year.get(), rating.get(), duration.get(), listed_in.get()`.
# >   >   5.2. Crear el registro en la BBDD con todos los datos incluidos usando las instrucciones apropiadas.
# >   >   5.3. Enviar un mensaje de registro agregado a través de la función con los argumentos mostrados `mensaje_registro(datos, 'agregado')`.
#
# Puedes ver un video en esta [lista de videos](https://www.youtube.com/playlist?list=PLekPxmjL0BEjGAb86Lw4quN3QucsaiGF_) con un ejemplo de esta función en otro contexto.

# %% [markdown]
# ##### G. Leer
# + `def leer_general` para leer los registros de la BBDD está ubicado debajo del comentario **<font color='#406040'># READ </font>**.
# Que debe hacer la función:
# >   1. Llamar a la función `leer_campo()` usando entre los  argumentos el título y almacenar el resultado de la query. **<font color='blue'>Tips</font>** la función requiere 3 argumentos la variable que lee desde la interfaz, el nombre del campo (un string) y el nombre de la columna de la BBDD.
# >   2. Si no existe el título, , usando la función `mensaje_campo_existe_o_no(title_content.get(), 'título', 'no')` con esos argumentos, debe enviar un mensaje de que el campo no existe.
# >   3. Si existe el título debe llamar a la función `rellenar_campos()` con el resultado almacenado como argumento.
#
# Puedes ver un video en esta [lista de videos](https://www.youtube.com/playlist?list=PLekPxmjL0BEjGAb86Lw4quN3QucsaiGF_) con un ejemplo de esta función en otro contexto.

# %% [markdown]
# ##### H. Actualizar
# + `def actualizar` para actualizar los registros de la BBDD está ubicado debajo del comentario **<font color='#406040'># UPDATE/Actualizar</font>**.
# ¿Qué debe hacer la función?:
# >   1. Crear una tupla a partir de `datos = type.get(), title_content.get(), director.get(), country.get(), release_year.get(), rating.get(), duration.get(), listed_in.get()`.
# >   2. Actualizar el registro en la BBDD con todos los datos incluidos, por medio de las instrucciones apropiadas.
# >   3. Enviar un mensaje de registro agregado a través de la función `mensaje_registro(datos, 'actualizado')`.
# >   4. Llamar a la función `limpiar()`.
#
# Puedes ver un video en esta [lista de videos](https://www.youtube.com/playlist?list=PLekPxmjL0BEjGAb86Lw4quN3QucsaiGF_) con un ejemplo de esta función en otro contexto.

# %% [markdown]
# ##### I. Borrar
# + `def borrar` para borrar los registros de la BBDD está ubicado debajo del comentario **<font color='#406040'># DELETE</font>**.
# ¿Qué debe hacer la función?:
# >   1. Llamar a la función `leer_campo()` usando entre los  argumentos el título y almacenar el resultado de la query. **<font color='blue'>Tips</font>** la función requiere 3 argumentos la variable que lee de la interfaz, el nombre del campo (un string) y el nombre de la columna de la BBDD.
# >   3. Si no existe el título, , usando la función `mensaje_campo_existe_o_no(title_content.get(), 'título', 'no')` con esos argumentos, debe enviar un mensaje de que el campo no existe.
# >   4. Si existe el título debe llamar a la función `rellenar_campos()` con el resultado almacenado como argumento.
# >   4. Eliminar el registro.
# >   5. Enviar un mensaje de registro eliminado a través de la función `mensaje_registro(*, 'eliminado')`, reemplazando \* por el resultado almacenado en el punto 1 solo el primer registro de la lista.
# >   6. Llamar a la función `limpiar()`.
#
# Puedes ver un video en esta [lista de videos](https://www.youtube.com/playlist?list=PLekPxmjL0BEjGAb86Lw4quN3QucsaiGF_) con un ejemplo de esta función en otro contexto.

# %% [markdown]
# 4. <font color='green'>**DESAFIOS**</font>:
#     * Respecto al punto 1.1 y 1.2 coloca el código final en la celda de deepnote en condiciones para que pueda ser ejecutado.
#     * Compartir los archivos siguientes, algunos en la carpeta **Mi_proyecto** otros solo el link de su ubicación en drive:
#         + El link de tu archivo de colab **conexion_colab** (con capacidad de edición)
#         + El archivo **<font color='red'>crud_netflix_mod.py</font>** obtenido en el punto 2, compartido en la carpeta.
#
#     * Comparte imágenes que muestren el cumplimiento de cada uno de las operaciones a modo de ejemplo del punto 2.
#
#     Adicionalmente puedes intentar las siguientes consignas :
#
# I.    Crear estructura de control  dentro de la función correspondiente que haga que la función solo se ejecute en el caso que check_conn indique que está conectado y en otro caso envie un mensaje que no se está conectado con la función `mensaje_noconectado()`. Considere que la estructura control puede detener la ejecución cuando no cumpla alguna condición deseada. Se puede aplicar a cada operación Crear, Leer, Actualizar y Borrar.
# II.   Crear una estructura de control que usando el método `askquestion` del objeto `messagebox` informe que no se ejecutó la operación leer de la BBDD y pregunte si quiere ejecutarla para proteger la ejecución de la operación actualizar.
# III.  Crear una estructura de control el método `askquestion` del objeto `messagebox` manejar con respuesta "yes/no" la eliminación del registro, tipo pregunta ¿Desea eliminar el registro?.
# IV.   Crear una estructura de control los métodos `askquestion` y `askyesnocancel` del objeto `messagebox` manejar con respuesta "yes/no" y "yes/no/cancel" la desconexión o no pero incluya la salida o no de la app, tipo pregunta ¿Desea salir de la app?, pero también considere que pueda estar conectado o no para la toma de decisión.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9f460218-f27a-46da-b92c-be792f72a006' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
